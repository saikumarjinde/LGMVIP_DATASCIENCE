# %% [markdown]
# # LETS GROW MORE   |    TASK 1

# %% [markdown]
# # DATASET INFORMATION

# %% [markdown]
# #### The Dataset contains 3 classes of 50 instances each...where each class refers to a type of iris plant. One class is linearly separable from the other 2, The latter are not linearly separable from each other

# %% [markdown]
# ##### Attributes Information:
#     1. sepal_length in cm
#     2. sepal_width in cm
#     3. petal_length in cm
#     4. petal_width in cm
#     5. class -- Iris Setosa - Iris Versicolour - iris Vigrinica
#     6. Number of Instances: 150 (50 in each of three classes)
#     7. Number of Attributes: 4 numeric,1 object
#     8. Class Distribution: 33.3% for each of 3 classes

# %% [markdown]
# #### IMPORT MODULES

# %%
#importing libraries for further use
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
import sklearn.preprocessing
import scipy

# %% [markdown]
# #### LOAD DATASET

# %%
#loading the data
df = pd.read_csv('IRIS.csv')

# %%
#vieweing the dataset for top 5 rows
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df['species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# #### SUMMARIZATION OF DATA

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# #### PREPROCESSING THE DATASET

# %%
df.isnull().sum()
#checking for null values
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
#Showing nullvalues in percentage format
missing_values = df.isnull().sum()
total = df.isnull().sum().sort_values(ascending = False)
percent = ((df.isnull().sum()/df.shape[0]*100))
percent = percent.sort_values(ascending = False)
missing_data = pd.concat([total,percent],axis = 1,
                        keys = ['Total Missing Values','Percentage of Missing values'])
missing_data['data(dtypes)'] = df[missing_data.index].dtypes
missing_data
# Out:
#               Total Missing Values  Percentage of Missing values data(dtypes)
# sepal_length                     0                           0.0      float64
# sepal_width                      0                           0.0      float64
# petal_length                     0                           0.0      float64
# petal_width                      0                           0.0      float64
# species                          0                           0.0       object

# %%
#visualization of NaN values using heatmap
sns.heatmap(df.isnull(),cbar = False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### EXPLORATORY DATA ANALYSIS

# %%
#Analyzing using histogram for columns in dataset
df['sepal_length'].hist()
# Out:
# <AxesSubplot:>

# %%
df['petal_length'].hist()
# Out:
# <AxesSubplot:>

# %%
df['sepal_width'].hist()
# Out:
# <AxesSubplot:>

# %%
df['petal_width'].hist()
# Out:
# <AxesSubplot:>

# %%
#scatter plot
colors = ['red','orange','blue']
species = ['Iris-virginica','Iris-versicolor','Iris-setosa']

# %%
for i in range(3):
    x = df[df['species'] == species[i]]
    plt.scatter(x['sepal_length'],x['sepal_width'], c = colors[i],label = species[i])
plt.legend()
plt.xlabel('Sepal_Length')
plt.ylabel('Sepal_width')
# Out:
# Text(0, 0.5, 'Sepal_width')

# %%
for i in range(3):
    x = df[df['species'] == species[i]]
    plt.scatter(x['petal_length'],x['petal_width'], c = colors[i],label = species[i])
plt.legend()
plt.xlabel('Petal_Length')
plt.ylabel('Petal_width')
# Out:
# Text(0, 0.5, 'Petal_width')

# %%
for i in range(3):
    x = df[df['species'] == species[i]]
    plt.scatter(x['sepal_length'],x['petal_length'], c = colors[i],label = species[i])
plt.legend()
plt.xlabel('Sepal_Length')
plt.ylabel('Petal_Lenth')
# Out:
# Text(0, 0.5, 'Petal_Lenth')

# %%
for i in range(3):
    x = df[df['species'] == species[i]]
    plt.scatter(x['sepal_width'],x['petal_width'], c = colors[i],label = species[i])
plt.legend()
plt.xlabel('Sepal_width')
plt.ylabel('Petal_width')
# Out:
# Text(0, 0.5, 'Petal_width')

# %%
sns.pairplot(df)

# %% [markdown]
# #### CORRELATION MATRIX FOR DATASET

# %% [markdown]
# A Correlation Matrix is a table showing correlation Coefficient between variables... Each cell in a table shows the Correlation
# between two Variables...The value is in the range 0 and 1...If two variables have high Correlation, then we can neglect
# one variable from those two...

# %%
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
sns.heatmap(df.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### LABEL ENCODER

# %% [markdown]
# In ML,We usually deal with dataset which contain multiple labels in one or more than one columns...These labels can be in the
# form of words or numbers...Label Encoding refers to converting the labels in numerical form...
# So as to convert it into Machine Readable form

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder
labelencode = LabelEncoder()
df['species'] = labelencode.fit_transform(df['species'])

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
df['species'].unique()
# Out:
# array([0, 1, 2])

# %% [markdown]
# #### DATA SPLITING

# %%
from sklearn.model_selection import train_test_split

# %%
#training the model
#training data = 70%
#testing data = 30%
#splitting data using X and Y varibles
X = df.values[:,0:4]
Y = df.values[:,4]

# %%
len(Y)
# Out:
# 150

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.30)

# %%
#lets know the length
len(X_train)
# Out:
# 105

# %%
len(X_test)
# Out:
# 45

# %%
len(Y_train)
# Out:
# 105

# %%
len(Y_test)
# Out:
# 45

# %%
Y_test
# Out:
# array([0., 1., 0., 2., 2., 2., 2., 1., 0., 1., 0., 1., 2., 2., 1., 2., 0.,
#        1., 2., 1., 0., 2., 2., 0., 1., 2., 0., 0., 0., 0., 1., 2., 1., 0.,
#        0., 1., 0., 0., 1., 2., 1., 0., 1., 2., 2.])

# %% [markdown]
# #### USING MODEL ALGORITHMS

# %% [markdown]
# ##### Model 1: Logistic Regression

# %%
#logistic regression
from sklearn.linear_model import LogisticRegression
model1 = LogisticRegression()

# %%
#using logistic regression
from warnings import filterwarnings
filterwarnings('ignore')
model1.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
#prediction
pre1 = model1.predict(X_test)

# %%
#findinng the accuracy
print("The Accuracy : ",model1.score(X_test,Y_test) * 100)
# Out:
# The Accuracy :  95.55555555555556

# %%
len(pre1)
# Out:
# 45

# %%
for i in range(len(pre3)):
    print("The given Data is:  ",X_test[i],"The predicted Output is:   ","-->>",pre1[i])
#0 indicates Iris-setosa
#1 indicates Iris-Versicolor
#2 indicates Iris-virginica
# Out:
# The given Data is:   [5.1 3.8 1.9 0.4] The predicted Output is:    -->> 0.0
# The given Data is:   [5.6 2.7 4.2 1.3] The predicted Output is:    -->> 1.0
# The given Data is:   [4.7 3.2 1.3 0.2] The predicted Output is:    -->> 0.0
# The given Data is:   [5.9 3.  5.1 1.8] The predicted Output is:    -->> 2.0
# The given Data is:   [6.3 2.5 5.  1.9] The predicted Output is:    -->> 2.0
# The given Data is:   [6.5 3.  5.5 1.8] The predicted Output is:    -->> 2.0
# The given Data is:   [5.8 2.7 5.1 1.9] The predicted Output is:    -->> 2.0
# The given Data is:   [4.9 2.4 3.3 1. ] The predicted Output is:    -->> 1.0
# The given Data is:   [4.6 3.1 1.5 0.2] The predicted Output is:    -->> 0.0
# The given Data is:   [6.6 2.9 4.6 1.3] The predicted Output is:    -->> 1.0
# The given Data is:   [5.1 3.5 1.4 0.3] The predicted Output is:    -->> 0.0
# The given Data is:   [5.7 2.6 3.5 1. ] The predicted Output is:    -->> 1.0
# ...

# %% [markdown]
# #### CLASSIFICATION REPORT FOR LOGISTIC REGRESSION

# %%
#performing classsification report
from sklearn.metrics import classification_report
print(classification_report(Y_test,pre1))

# %% [markdown]
# #### MODEL 2: K-NEAREST NEIGHBORS

# %%
#IMPORTING KNN
from sklearn.neighbors import KNeighborsClassifier
model2 = KNeighborsClassifier()

# %%
model2.fit(X_train,Y_train)

# %%
#findinng the accuracy
print("The Accuracy : ",model2.score(X_test,Y_test) * 100)

# %%
pre2 = model2.predict(X_test)

# %%
len(pre2)

# %%
for i in range(len(pre3)):
    print("The given Data is:  ",X_test[i],"The predicted Output is:   ","-->>",pre2[i])

# %% [markdown]
# #### CLASSIFICATION REPORT FOR KNN

# %%
#performing classsification report
from sklearn.metrics import classification_report
print(classification_report(Y_test,pre2))

# %% [markdown]
# #### MODEL 3: DECISION TREE

# %%
from sklearn.tree import DecisionTreeClassifier
model3 = DecisionTreeClassifier()

# %%
model3
# Out:
# DecisionTreeClassifier()

# %%
model3.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
#findinng the accuracy
print("The Accuracy : ",model3.score(X_test,Y_test) * 100)
# Out:
# The Accuracy :  97.77777777777777

# %%
pre3 = model3.predict(X_test)

# %%
pre3
# Out:
# array([0., 1., 0., 2., 2., 2., 2., 1., 0., 1., 0., 1., 2., 2., 1., 2., 0.,
#        1., 2., 2., 0., 2., 2., 0., 1., 2., 0., 0., 0., 0., 1., 2., 1., 0.,
#        0., 1., 0., 0., 1., 2., 1., 0., 1., 2., 2.])

# %%
len(pre3)
# Out:
# 45

# %%
for i in range(len(pre3)):
    print("The given Data is:  ",X_test[i],"The predicted Output is:   ","-->>",pre3[i])
# Out:
# The given Data is:   [5.1 3.8 1.9 0.4] The predicted Output is:    -->> 0.0
# The given Data is:   [5.6 2.7 4.2 1.3] The predicted Output is:    -->> 1.0
# The given Data is:   [4.7 3.2 1.3 0.2] The predicted Output is:    -->> 0.0
# The given Data is:   [5.9 3.  5.1 1.8] The predicted Output is:    -->> 2.0
# The given Data is:   [6.3 2.5 5.  1.9] The predicted Output is:    -->> 2.0
# The given Data is:   [6.5 3.  5.5 1.8] The predicted Output is:    -->> 2.0
# The given Data is:   [5.8 2.7 5.1 1.9] The predicted Output is:    -->> 2.0
# The given Data is:   [4.9 2.4 3.3 1. ] The predicted Output is:    -->> 1.0
# The given Data is:   [4.6 3.1 1.5 0.2] The predicted Output is:    -->> 0.0
# The given Data is:   [6.6 2.9 4.6 1.3] The predicted Output is:    -->> 1.0
# The given Data is:   [5.1 3.5 1.4 0.3] The predicted Output is:    -->> 0.0
# The given Data is:   [5.7 2.6 3.5 1. ] The predicted Output is:    -->> 1.0
# ...

# %% [markdown]
# #### CLASSIFICATION REPORT FOR DECISION TREE

# %%
#performing classsification report
from sklearn.metrics import classification_report
print(classification_report(Y_test,pre3))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        16
#          1.0       1.00      0.93      0.96        14
#          2.0       0.94      1.00      0.97        15
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45

# %% [markdown]
# #### MODEL 4: SUPPORT VECTOR MACHINE

# %%
from sklearn.svm import SVC
model4 = SVC()
model4.fit(X_train,Y_train)
# Out:
# SVC()

# %%
model4.fit(X_train,Y_train)
# Out:
# SVC()

# %%
#findinng the accuracy
print("The Accuracy : ",model4.score(X_test,Y_test) * 100)
# Out:
# The Accuracy :  93.33333333333333

# %%
pre4 = model4.predict(X_test)

# %%
len(pre4)
# Out:
# 45

# %%
for i in range(len(pre3)):
    print("The given Data is:  ",X_test[i],"The predicted Output is:   ","-->>",pre4[i])
# Out:
# The given Data is:   [5.1 3.8 1.9 0.4] The predicted Output is:    -->> 0.0
# The given Data is:   [5.6 2.7 4.2 1.3] The predicted Output is:    -->> 1.0
# The given Data is:   [4.7 3.2 1.3 0.2] The predicted Output is:    -->> 0.0
# The given Data is:   [5.9 3.  5.1 1.8] The predicted Output is:    -->> 2.0
# The given Data is:   [6.3 2.5 5.  1.9] The predicted Output is:    -->> 2.0
# The given Data is:   [6.5 3.  5.5 1.8] The predicted Output is:    -->> 2.0
# The given Data is:   [5.8 2.7 5.1 1.9] The predicted Output is:    -->> 2.0
# The given Data is:   [4.9 2.4 3.3 1. ] The predicted Output is:    -->> 1.0
# The given Data is:   [4.6 3.1 1.5 0.2] The predicted Output is:    -->> 0.0
# The given Data is:   [6.6 2.9 4.6 1.3] The predicted Output is:    -->> 1.0
# The given Data is:   [5.1 3.5 1.4 0.3] The predicted Output is:    -->> 0.0
# The given Data is:   [5.7 2.6 3.5 1. ] The predicted Output is:    -->> 1.0
# ...

# %% [markdown]
# #### CLASSIFICATION REPORT FOR SVM

# %%
#performing classsification report
from sklearn.metrics import classification_report
print(classification_report(Y_test,pre4))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        16
#          1.0       0.87      0.93      0.90        14
#          2.0       0.93      0.87      0.90        15
#
#     accuracy                           0.93        45
#    macro avg       0.93      0.93      0.93        45
# weighted avg       0.93      0.93      0.93        45
